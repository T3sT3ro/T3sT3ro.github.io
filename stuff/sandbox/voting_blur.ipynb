# %%
ll

# %%
import cv2 as cv
import numpy as np
import scipy.io as sio
import scipy as sc
import matplotlib.pyplot as plt
import pandas as pd
import random
from ipycanvas import Canvas
from keras.datasets import cifar10

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
(x_data, y_data), (x_test, y_test) = cifar10.load_data()
plt.xkcd()
print(x_data.shape)
print(y_data.shape)
plt.imshow(random.choice(x_data))
plt.xlabel("width")
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# Text(0.5, 0, 'width')
